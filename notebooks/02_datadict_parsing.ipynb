# %%
import sys, re
sys.path.append('..')

from src.datadict import DataDictionary

# %%
datadict = DataDictionary.from_csv("../data/datadict.csv")

# %%
datadict.fields[5:10]
# Out:
# [DataDictionaryField(field_name='height', form_name='demography', field_type=<FieldType.TEXT: 'text'>, field_label='Height', choices=None, calculation=None, validation_type=<ValidationType.NUMBER: 'number'>, validation_minimum=120, validation_maximum=210, identifier=False, branching_logic=None, required_field=False),
#  DataDictionaryField(field_name='bmi', form_name='demography', field_type=<FieldType.CALC: 'calc'>, field_label='BMI', choices=None, calculation=None, validation_type=None, validation_minimum=None, validation_maximum=None, identifier=False, branching_logic=None, required_field=False),
#  DataDictionaryField(field_name='cied', form_name='medical_history', field_type=<FieldType.YESNO: 'yesno'>, field_label='Cardiovascular Implantable Electronic Device', choices=None, calculation=None, validation_type=None, validation_minimum=None, validation_maximum=None, identifier=False, branching_logic=None, required_field=True),
# ...

# %%
# Check coices for checkbox field
next((i for i in datadict.fields if re.match(r"checkbox", i.field_type)), None)
# Out:
# DataDictionaryField(field_name='history_arrhythmia_spec', form_name='medical_history', field_type=<FieldType.CHECKBOX: 'checkbox'>, field_label='Cardiac Arrhythmia ', choices={'Atrial Fibrillation': 1, 'Atrial Flutter': 2, 'Ventricular Tachycardia': 3, 'Ventricular Fibrillation': 4, 'AV-Block II': 5, 'AV-Block III': 6, 'Sinus node dysfunction': 7}, calculation=None, validation_type=None, validation_minimum=None, validation_maximum=None, identifier=False, branching_logic=[{'field': 'history_arrhythmia', 'operator': '=', 'value': 1}], required_field=False)
