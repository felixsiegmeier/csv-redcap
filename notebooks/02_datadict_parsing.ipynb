# %%
import sys
sys.path.append('..')

from src.datadict import DataDictionary
# Out:
#   Cell In[4], line 1
#     from ../src/datadict.py import DataDictionary
#            ^
# SyntaxError: invalid syntax
