# %%
import pandas as pd

datadict = "../data/datadict.csv"
df = pd.read_csv(datadict, sep=';', encoding='utf-8')

# %%
# Display all Columns and their unique value counts
for column in df.columns:
    print(f"{column}: {df[column].unique().shape[0]}")
# Out:
# Variable / Field Name: 853
# Form Name: 31
# Section Header: 34
# Field Type: 8
# Field Label: 635
# Choices, Calculations, OR Slider Labels: 193
# Field Note: 95
# Text Validation Type OR Show Slider Number: 9
# Text Validation Min: 41
# Text Validation Max: 59
# Identifier?: 2
# Branching Logic (Show field only if...): 291
# Required Field?: 2
# Custom Alignment: 2
# Question Number (surveys only): 1
# Matrix Group Name: 1
# Matrix Ranking?: 1
# Field Annotation: 9

# %% [markdown]
# # Relevante Spalten:
# - Variable / Field Name
# - Form Name
# - Field Type
# - Field Label
# - Choices, Calculations, OR Slider Labels
# - Text Validation Type OR Show Slider Number
# - Text Validation Min
# - Text Validation Max
# - Identifier?
# - Branching Logic (Show field only if...)
# - Required Field?

# %%
df['Form Name'].unique()
# Out:
# array(['demography', 'medical_history', 'vascular_diseases', 'surgery',
#        'coronary_angiography', 'echocardiography', 'infections',
#        'outcome', 'additional_mcs', 'prevaecls',
#        'prevaecls_hemodynamics_ventilation_labor', 'eclsmode',
#        'eclsequipment', 'eclsassessment_first', 'pump',
#        'discontinuation_vaecls', 'preimpella',
#        'preimpella_hemodynamics_ventilation_labor',
#        'mode_and_equipment_impella',
#        'impellaassessment_and_complications',
#        'hemodynamics_ventilation_medication', 'labor', 'complications',
#        'discontinuation_impella', 'impella_follow_up', 'eq5d5l', 'sf12v2',
#        'calculation', 'calculation_ecls', 'aki_william', 'cabg'],
#       dtype=object)

# %%
df["Field Type"].unique()
# Out:
# array(['text', 'radio', 'dropdown', 'calc', 'yesno', 'checkbox', 'notes',
#        'descriptive'], dtype=object)

# %%
df["Text Validation Type OR Show Slider Number"].unique()
# Out:
# array([nan, 'date_dmy', 'number', 'alpha_only',
#        'number_1dp_comma_decimal', 'time', 'datetime_dmy',
#        'number_2dp_comma_decimal', 'integer'], dtype=object)

# %%
df["Text Validation Min"].unique()
# Out:
# array([nan, '1920-01-01', '30', '120', '0', '0,5', '0,2', '5', '40', '10',
#        '1990-01-01', '1', '0,01', '0,05', '15,0', '20,0', '6,80', '5,0',
#        '-25,0', '1,5', '110', '30,0', '20', '34,0', '0,1', '3', '4,5',
#        '70,0', '10,0', '1,0', '0,00', '22,0', '90', '4,0', '1,00', '8,0',
#        '2010-01-01', '100000', '5000,00', '0,0', '2015-01-01'],
#       dtype=object)

# %%
df["Text Validation Max"].unique()
# Out:
# array([nan, '2020-01-01', '200', '210', '400', '2030-01-01', '12,0',
#        '6,0', '55', '80', '90', '10,00', '1,00', '120,0', '600,0', '7,70',
#        '50,0', '25,0', '9,0', '160', '100,0', '500', '250', '20', '100',
#        '1000', '40', '45', '30', '40,0', '25', '7,0', '15', '30,0',
#        '20,0', '60,0', '99,0', '15,0', '800', '10,0', '180,0', '8,0',
#        '20000', '700', '200,0', '300,0', '150,00', '200,00', '10000',
#        '310000', '9', '40000,00', '35', '5,00', '5000', '10', '3000',
#        '4800', '40,00'], dtype=object)

# %%
df[df["Variable / Field Name"].isna()]
# Out:
# Empty DataFrame
# Columns: [Variable / Field Name, Form Name, Section Header, Field Type, Field Label, Choices, Calculations, OR Slider Labels, Field Note, Text Validation Type OR Show Slider Number, Text Validation Min, Text Validation Max, Identifier?, Branching Logic (Show field only if...), Required Field?, Custom Alignment, Question Number (surveys only), Matrix Group Name, Matrix Ranking?, Field Annotation]
# Index: []

# %%
df["Identifier?"].unique()
# Out:
# array([nan, 'y'], dtype=object)

# %%
df["Required Field?"].unique()
# Out:
# array([nan, 'y'], dtype=object)

# %%
df["Branching Logic (Show field only if...)"].unique()
# Out:
# array([nan, "[cied] = '1'", "[history_arrhythmia] = '1'",
#        "[diabetes] = '1'", "[ckd]='1'", "[antiplat_th] = '1'",
#        "[antiplat_therapy_spec(5)] = '1'", "[oak] = '1'",
#        "[oak_spec] = '5'", "[onco] = '1'", "[onco]='1'",
#        "[onco_therapy] = '1'", "[drugs] = '1'", "[copd] = '1'",
#        '[pulm_hypertension]="1"', "[stroke] = '1'",
#        '[art_hypertension]="1"', '[med_aht]="1"', "[pavk] = '1'",
#        "[pavk_stent]='1'", "[pavk_stent_side(1)] = '1'",
#        "[pavk_stent_side(2)] = '1'", "[pavk_op]='1'",
#        "[pavk_op_side(1)] = '1'", "[pavk_op_r_spec(3)] = '1'",
#        "[pavk_op_side(2)] = '1'", "[pavk_op_l_spec(3)] = '1'",
#        "[cavk] = '1'", "[cavk_op] = '1'", "[vasc_other] = '1'",
#        "[op_vasc_other] = '1'", "[surgery] = '1'", "[surgery_spec] = '1'",
#        "[heart_surgery_spec(16)] = '1'", "[hs_info]='1'",
#        "[surgery_spec] = '2'", "[ecls_surgery(3)] = '1'",
#        "[ecls_surgery(6)] = '1'", "[surgery_spec] = '4'",
# ...

# %%
df["Field Label"].unique()
# Out:
# array(['Record ID', 'Date of Birth', 'Sex', 'Race', 'Weight', 'Height',
#        'BMI', 'Cardiovascular Implantable Electronic Device',
#        'Form of CIED', 'Date of CIED Implantation',
#        'History of Cardiac Arrhythmia ', 'Cardiac Arrhythmia ',
#        'Diabetes mellitus ', 'Type of Diabetes mellitus',
#        'Chronic kidney disease', 'Stage of Chronic kidney disease',
#        'Antiplatelet Therapy', 'Specific Antiplatelet Therapy ',
#        'Other Antiplatelet Therapy', 'Oral Anticoagulation',
#        'Specific Oral Anticoagulation', 'Other Oral Anticoagulation',
#        'Oncological Diagnosis ', 'Oncological Diagnosis',
#        'History of Oncological Treatment',
#        'Form of Oncological Treatment', 'Date of Oncological Treatment',
#        'History of / current drug abuse ', 'Drug Types',
#        'Chronic obstructive pulmonary disease', 'Type of COPD ',
#        'Pulmonary Hypertension', 'Type of Pulmonary Hypertension',
# ...
